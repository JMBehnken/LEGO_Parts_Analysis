# %% [markdown]
# # Compute the price for all LEGO Bricks of a set

# %%
import re
import requests
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
from multiprocessing.dummy import Pool

# %%
LEGO_Set = '79003-1'

url_parts = 'https://www.bricklink.com/catalogItemInv.asp?S={}'.format(LEGO_Set)
url_minifigs = 'https://www.bricklink.com/catalogItemInv.asp?S={}&viewItemType=M'.format(LEGO_Set)

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
data = []

bs = BeautifulSoup(requests.get(url_parts, headers=headers).text, 'lxml')
for elem in bs.find('table', {'class':'ta'}).findAll('tr'):
    try:
        tds = elem.findAll('td')
        quantity = int(tds[1].get_text())
        url = tds[2].find('a')['href']
        data.append([quantity, url])
    except:
        pass

bs = BeautifulSoup(requests.get(url_minifigs, headers=headers).text, 'lxml')
for elem in bs.find('table', {'class':'ta'}).findAll('tr'):
    try:
        tds = elem.findAll('td')
        quantity = int(tds[1].get_text())
        url = tds[2].find('a')['href']
        data.append([quantity, url])
    except:
        pass
    
df = pd.DataFrame(data, columns=['Quantity', 'URL'])
df.head(2)
# Out:
#    Quantity                                                URL
# 0         1  /v2/catalog/catalogitem.page?P=79003stk01&idCo...
# 1         1     /v2/catalog/catalogitem.page?P=3659&idColor=11

# %%
re_part = re.compile('P=(.+)&')
re_color = re.compile('idColor=(\d+)')

# %%
def scrapeBricks(link):
    try:
        part = re.search(re_part, link)[1]
        color = re.search(re_color, link)[1]
        
        url = url_price.format(part, color)
    except:
        part = 'missing'
        color = 'missing'
        url = 'https://www.bricklink.com{}'.format(link)
    
    price = 0
    bs = BeautifulSoup(requests.get(url, headers=headers).text, 'lxml')
    try:
        for elem in bs.find('table', {'class':'fv'}).findAll('tr'):
            text = elem.get_text()
            s = re.search('Qty Avg Price:EUR(.+?)Max', text)
            if s:
                price = float(s[1].strip())
                break
    except:
        pass
    return [part, color, price, link]

# %%
url_price = 'https://www.bricklink.com/catalogPG.asp?P={}&ColorID={}'

data = []
futures = []
pool = Pool(2)

for link in df['URL'].values:
    futures.append(pool.apply_async(scrapeBricks, [link]))
for brick in tqdm(futures):
    data.append(brick.get())
# Out:
# 100%|██████████| 228/228 [08:09<00:00,  1.82it/s]

# %%
df_parts = pd.DataFrame(data, columns=['Part', 'Color', 'Price', 'URL'])
df = df.merge(df_parts, on='URL', how='outer')

# %%
df
# Out:
#      Quantity                                                URL         Part  \
# 0           1  /v2/catalog/catalogitem.page?P=79003stk01&idCo...   79003stk01
# 1           1     /v2/catalog/catalogitem.page?P=3659&idColor=11         3659
# 2           1     /v2/catalog/catalogitem.page?P=3633&idColor=11         3633
# 3           1     /v2/catalog/catalogitem.page?P=6134&idColor=11         6134
# 4           1     /v2/catalog/catalogitem.page?P=4332&idColor=11         4332
# 5           1     /v2/catalog/catalogitem.page?P=4528&idColor=11         4528
# 6           2     /v2/catalog/catalogitem.page?P=4529&idColor=11         4529
# 7           1    /v2/catalog/catalogitem.page?P=4864b&idColor=11        4864b
# 8           1     /v2/catalog/catalogitem.page?P=3024&idColor=11         3024
# 9           1     /v2/catalog/catalogitem.page?P=3024&idColor=11         3024
# 10          1     /v2/catalog/catalogitem.page?P=3024&idColor=11         3024
# 11          1     /v2/catalog/catalogitem.page?P=3024&idColor=11         3024
# 12          1     /v2/catalog/catalogitem.page?P=3023&idColor=11         3023
# 13          3     /v2/catalog/catalogitem.page?P=3710&idColor=11         3710
# 14          2    /v2/catalog/catalogitem.page?P=63868&idColor=11        63868
# 15          2    /v2/catalog/catalogitem.page?P=60478&idColor=11        60478
# 16          1     /v2/catalog/catalogitem.page?P=3184&idColor=11         3184
# 17          3     /v2/catalog/catalogitem.page?P=2555&idColor=11         2555
# 18          1   /v2/catalog/catalogitem.page?P=30350c&idColor=11       30350c
# 19          4     /v2/catalog/catalogitem.page?P=3680&idColor=11         3680
# 20          4    /v2/catalog/catalogitem.page?P=30046&idColor=11        30046
# 21          2    /v2/catalog/catalogitem.page?P=33051&idColor=36        33051
# 22          7    /v2/catalog/catalogitem.page?P=33183&idColor=36        33183
# 23          7    /v2/catalog/catalogitem.page?P=33183&idColor=36        33183
# 24          1    /v2/catalog/catalogitem.page?P=33183&idColor=36        33183
# 25          1    /v2/catalog/catalogitem.page?P=33183&idColor=36        33183
# 26          2     /v2/catalog/catalogitem.page?P=2417&idColor=36         2417
# 27         10    /v2/catalog/catalogitem.page?P=54200&idColor=36        54200
# 28         10    /v2/catalog/catalogitem.page?P=54200&idColor=36        54200
# 29          3    /v2/catalog/catalogitem.page?P=54200&idColor=36        54200
# ..        ...                                                ...          ...
# 248         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 249         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 250         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 251         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 252         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 253         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 254         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 255         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 256         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 257         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 258         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 259         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 260         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 261         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 262         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 263         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 264         2  /v2/catalog/catalogitem.page?P=33172c01&idColor=4     33172c01
# 265         1  /v2/catalog/catalogitem.page?P=4738ac01&idColo...     4738ac01
# 266         1  /v2/catalog/catalogitem.page?P=33009pb039&idCo...   33009pb039
# 267         1  /v2/catalog/catalogitem.page?P=2431pb282&idCol...    2431pb282
# 268         1  /v2/catalog/catalogitem.page?P=6636pb070&idCol...    6636pb070
# 269         2  /v2/catalog/catalogitem.page?P=4162pb092&idCol...    4162pb092
# 270         1  /v2/catalog/catalogitem.page?P=3068bpb0639&idC...  3068bpb0639
# 271         1  /v2/catalog/catalogitem.page?P=3068bpb0640&idC...  3068bpb0640
# 272         1  /v2/catalog/catalogitem.page?P=3068bpb0641&idC...  3068bpb0641
# 273         1    /v2/catalog/catalogitem.page?P=87552&idColor=11        87552
# 274         1   /v2/catalog/catalogitem.page?P=30350b&idColor=11       30350b
# 275         5     /v2/catalog/catalogitem.page?P=3794&idColor=88         3794
# 276         1   /v2/catalog/catalogitem.page?P=30350b&idColor=88       30350b
# 277         1      /v2/catalog/catalogitem.page?P=4865&idColor=2         4865
#
#        Color  Price
# 0          0   1.99
# 1         11   0.05
# 2         11   0.08
# 3         11   0.05
# 4         11   0.16
# 5         11   0.07
# 6         11   0.06
# 7         11   0.14
# 8         11   0.05
# 9         11   0.05
# 10        11   0.05
# 11        11   0.05
# 12        11   0.03
# 13        11   0.05
# 14        11   0.03
# 15        11   0.03
# 16        11   0.08
# 17        11   0.07
# 18        11   0.06
# 19        11   0.03
# 20        11   0.16
# 21        36   0.16
# 22        36   0.05
# 23        36   0.05
# 24        36   0.05
# 25        36   0.05
# 26        36   0.24
# 27        36   0.05
# 28        36   0.05
# 29        36   0.05
# ..       ...    ...
# 248  missing   0.00
# 249  missing   0.00
# 250  missing   0.00
# 251  missing   0.00
# 252  missing   0.00
# 253  missing   0.00
# 254  missing   0.00
# 255  missing   0.00
# 256  missing   0.00
# 257  missing   0.00
# 258  missing   0.00
# 259  missing   0.00
# 260  missing   0.00
# 261  missing   0.00
# 262  missing   0.00
# 263  missing   0.00
# 264        4   0.24
# 265       88   0.18
# 266       88   2.17
# 267       88   0.25
# 268       88   0.44
# 269       88   0.40
# 270        2   0.71
# 271        2   0.82
# 272        2   0.55
# 273       11   0.05
# 274       11   0.03
# 275       88   0.07
# 276       88   0.03
# 277        2   0.06
#
# [278 rows x 5 columns]

# %%
df['All_Price'] = df['Quantity']*df['Price']

# %%
df.sort_values('All_Price', ascending=False)
# Out:
#      Quantity                                                URL         Part  \
# 62          2    /v2/catalog/catalogitem.page?P=92438&idColor=69        92438
# 266         1  /v2/catalog/catalogitem.page?P=33009pb039&idCo...   33009pb039
# 0           1  /v2/catalog/catalogitem.page?P=79003stk01&idCo...   79003stk01
# 161        25    /v2/catalog/catalogitem.page?P=3062b&idColor=88        3062b
# 99          1     /v2/catalog/catalogitem.page?P=92438&idColor=6        92438
# 202         5      /v2/catalog/catalogitem.page?P=3008&idColor=2         3008
# 160        14     /v2/catalog/catalogitem.page?P=4070&idColor=88         4070
# 139        14   /v2/catalog/catalogitem.page?P=3069b&idColor=150        3069b
# 135        10   /v2/catalog/catalogitem.page?P=98283&idColor=150        98283
# 201         7      /v2/catalog/catalogitem.page?P=3009&idColor=2         3009
# 97          3      /v2/catalog/catalogitem.page?P=3036&idColor=6         3036
# 209        12     /v2/catalog/catalogitem.page?P=87087&idColor=2        87087
# 93         12      /v2/catalog/catalogitem.page?P=3020&idColor=6         3020
# 271         1  /v2/catalog/catalogitem.page?P=3068bpb0640&idC...  3068bpb0640
# 106         4      /v2/catalog/catalogitem.page?P=3297&idColor=6         3297
# 269         2  /v2/catalog/catalogitem.page?P=4162pb092&idCol...    4162pb092
# 83          1      /v2/catalog/catalogitem.page?P=6064&idColor=6         6064
# 75          2      /v2/catalog/catalogitem.page?P=2357&idColor=6         2357
# 176        24     /v2/catalog/catalogitem.page?P=4073&idColor=88         4073
# 177        24     /v2/catalog/catalogitem.page?P=4073&idColor=88         4073
# 82          3      /v2/catalog/catalogitem.page?P=2417&idColor=6         2417
# 57          4    /v2/catalog/catalogitem.page?P=30044&idColor=80        30044
# 270         1  /v2/catalog/catalogitem.page?P=3068bpb0639&idC...  3068bpb0639
# 120         4     /v2/catalog/catalogitem.page?P=87079&idColor=6        87079
# 193         4     /v2/catalog/catalogitem.page?P=4162&idColor=88         4162
# 20          4    /v2/catalog/catalogitem.page?P=30046&idColor=11        30046
# 109         9     /v2/catalog/catalogitem.page?P=3684c&idColor=6        3684c
# 158         3    /v2/catalog/catalogitem.page?P=76768&idColor=88        76768
# 220         4      /v2/catalog/catalogitem.page?P=6636&idColor=2         6636
# 110        10     /v2/catalog/catalogitem.page?P=61678&idColor=6        61678
# ..        ...                                                ...          ...
# 145         1    /v2/catalog/catalogitem.page?P=4073&idColor=115         4073
# 144         1    /v2/catalog/catalogitem.page?P=4073&idColor=115         4073
# 230         1     /v2/catalog/catalogitem.page?P=4073&idColor=98         4073
# 236         1     /v2/catalog/catalogitem.page?P=4073&idColor=19         4073
# 233         1     /v2/catalog/catalogitem.page?P=4073&idColor=19         4073
# 231         1     /v2/catalog/catalogitem.page?P=4073&idColor=98         4073
# 252         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 253         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 240         1              /v2/catalog/catalogitem.page?M=lor049      missing
# 241         1              /v2/catalog/catalogitem.page?M=lor049      missing
# 242         1              /v2/catalog/catalogitem.page?M=lor049      missing
# 243         1              /v2/catalog/catalogitem.page?M=lor049      missing
# 244         1              /v2/catalog/catalogitem.page?M=lor029      missing
# 245         1              /v2/catalog/catalogitem.page?M=lor029      missing
# 246         1              /v2/catalog/catalogitem.page?M=lor029      missing
# 247         1              /v2/catalog/catalogitem.page?M=lor029      missing
# 248         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 249         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 250         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 263         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 262         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 261         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 260         1              /v2/catalog/catalogitem.page?M=lor001      missing
# 259         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 258         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 251         1              /v2/catalog/catalogitem.page?M=lor052      missing
# 256         1              /v2/catalog/catalogitem.page?M=lor050      missing
# 255         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 254         1              /v2/catalog/catalogitem.page?M=lor051      missing
# 257         1              /v2/catalog/catalogitem.page?M=lor050      missing
#
#        Color  Price  All_Price
# 62        69   1.20       2.40
# 266       88   2.17       2.17
# 0          0   1.99       1.99
# 161       88   0.05       1.25
# 99         6   1.16       1.16
# 202        2   0.23       1.15
# 160       88   0.08       1.12
# 139      150   0.08       1.12
# 135      150   0.11       1.10
# 201        2   0.15       1.05
# 97         6   0.32       0.96
# 209        2   0.08       0.96
# 93         6   0.07       0.84
# 271        2   0.82       0.82
# 106        6   0.20       0.80
# 269       88   0.40       0.80
# 83         6   0.77       0.77
# 75         6   0.37       0.74
# 176       88   0.03       0.72
# 177       88   0.03       0.72
# 82         6   0.24       0.72
# 57        80   0.18       0.72
# 270        2   0.71       0.71
# 120        6   0.16       0.64
# 193       88   0.16       0.64
# 20        11   0.16       0.64
# 109        6   0.07       0.63
# 158       88   0.21       0.63
# 220        2   0.15       0.60
# 110        6   0.06       0.60
# ..       ...    ...        ...
# 145      115   0.01       0.01
# 144      115   0.01       0.01
# 230       98   0.01       0.01
# 236       19   0.01       0.01
# 233       19   0.01       0.01
# 231       98   0.01       0.01
# 252  missing   0.00       0.00
# 253  missing   0.00       0.00
# 240  missing   0.00       0.00
# 241  missing   0.00       0.00
# 242  missing   0.00       0.00
# 243  missing   0.00       0.00
# 244  missing   0.00       0.00
# 245  missing   0.00       0.00
# 246  missing   0.00       0.00
# 247  missing   0.00       0.00
# 248  missing   0.00       0.00
# 249  missing   0.00       0.00
# 250  missing   0.00       0.00
# 263  missing   0.00       0.00
# 262  missing   0.00       0.00
# 261  missing   0.00       0.00
# 260  missing   0.00       0.00
# 259  missing   0.00       0.00
# 258  missing   0.00       0.00
# 251  missing   0.00       0.00
# 256  missing   0.00       0.00
# 255  missing   0.00       0.00
# 254  missing   0.00       0.00
# 257  missing   0.00       0.00
#
# [278 rows x 6 columns]

# %%
df['All_Price'].sum()
# Out:
# 68.4899999999999
